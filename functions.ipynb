# %% [markdown]
# To make function you need to use "def" word. Then you add name of a function and in oval brackets the attributes of the function but it is not necessary

# %%
def sum_of_two(a,b):
    return a+b

# %% [markdown]
# To run this function you need to type name of the function "sum_of_two()" with owal brackets. In oval brackets you put some numbers, for example : 3, 4.

# %%
sum_of_two(3,4)
